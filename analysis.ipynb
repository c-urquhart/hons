# %%
# imports
import pandas as pd
import mysql.connector
import spacy
from nltk.stem import PorterStemmer

# %%
# function declarations

# get papers
def getPapers():
    connection = mysql.connector.connect(
        host="localhost",
        user="root",
        password="password",
        database="mysql"
    )

    # return papers into a pandas dataframe
    return pd.read_sql("SELECT id, title, author, abstract FROM papers", con=connection)

# to lowercase
def toLower(text):
    return text.astype(str).str.lower()

# function to tokenise text
def tokenise(text):
    sp = spacy.load("en_core_web_sm")
    return text.apply(lambda x: sp(x))

# function to remove punctuation instances
def removePunctuation(text):
    return text.str.replace('[^\w\s]','')

# function to remove stop words
def removeStops(text):
    sp = spacy.load("en_core_web_sm")
    stops = sp.Defaults.stop_words
    return [word for word in text if not word in stops]

# calculates and prints the similarity of documents
def getSimilarity(id):
    length = len(dfPapers)
    doc1 = dfPapers['abstract'].loc[0]
    print("Similarities to Document " + str(id+1))
    i = 0
    while i < length:
        if i != id:
            doc2 = dfPapers['abstract'].loc[i]
            print("Document " + str(i+1) + ", Title: " + str(dfPapers['title'].loc[0]) + ", Similarity: " + str(doc1.similarity(doc2)))
        i = i + 1

# %%
# database connection to get papers
dfPapers = getPapers()

print(dfPapers)
# Out:
#     id                                              title  \
# 0    1  A randomized, home-based, childhood obesity in...
# 1    5  A three-year multifaceted intervention to prev...
# 2    6  A behavioural change intervention study for th...
# 3    7  Family-based childhood obesity prevention inte...
# 4    8  A systematic review and meta-analysis of the o...
# 5    9  Growing Healthy Together: protocol for a rando...
# 6   10  OB CITY—Definition of a Family-Based Intervent...
# 7   11  Family-based, healthy living\r\nintervention f...
# 8   12  Short- and Long-Term Beneficial Effects of a C...
# 9   13  Effectiveness of a KindergartenBased Intervent...
# 10  14  Riding into Health: A Case Study on an Equine-...
# 11  15          Preventing childhood obesity: what works?
# 12  17  Evaluation and Treatment of Severe Obesity in ...
# 13  18   Prevention Models of Childhood Obesity in Sweden
# 14  19  Understanding a successful obesity prevention ...
# 15  20  The effect of comprehensive intervention for c...
# 16  21  Preventing childhood obesity: Contributions\r\...
# 17  22  Addressing Childhood Obesity: Opportunities fo...
#
#                                                author  \
# 0   Lourdes Yun, Richard E. Boles, Matthew A. Haem...
# 1   Banafsheh Sadeghil, Lucia L. Kaiser, Meagan M....
# 2      Natisha Dukhi, Benn Sartorius, and Myra Taylor
# 3   Tayla Ash, Alen Agaronov, Ta’Loria Young, Alys...
# 4   Zheng Liu1, Han-Meng Xu, Li-Ming Wen, Yuan-Zho...
# 5   Byron A. Foster, Kelsey Weinstein and Jackilen...
# 6   RUOFEI HU, JORGE CANCELA, MARIA TERESA ARREDON...
# 7   Sam Liu, Isabela Gouveia Marques , Megan A Per...
# 8   Dan Nemet, Sivan Barkan, Yoram Epstein, Orit F...
# 9   Yan Hu, Jian-Rong He, Fang-Hua Liu, Wei-Dong L...
# 10  Katy Schroeder, Jason Van Allen, Emily Dhurand...
# 11                            LL Birch and AK Ventura
# 12              Edmond P. Wickham, and Mark D. DeBoer
# 13                                 Carl-Erik Flodmark
# 14  Brynle Owen, Andrew D. Brown, Jill Kuhlberg, L...
# 15  Haiquan Xu, Olivier Ecker, Qian Zhang, Songmin...
# 16          Muriel Lamarque, and Alicia Bibiana Orden
# 17  Callie L. Brown, Elizabeth E. Halvorson, Gail ...
#
#                                              abstract
# 0   b'Background: Although Colorado is perceived a...
# 1   b'Background: Obesity and overweight have incr...
# 2   b'Background: South Africa is currently underg...
# 3   b'Background: A wide range of interventions ha...
# 4   b'Background: Childhood obesity is a serious p...
# 5   b'Background: Latino children in the US experi...
# 6   b'ABSTRACT Childhood obesity is becoming one o...
# 7   b'Introduction Family-based behavioural weight...
# 8   b'Background. Obesity has become the most comm...
# 9   b'BACKGROUND AND OBJECTIVES: Interventions to ...
# 10  b'Abstract: In this article, we present an exp...
# 11  b'Rates of overweight in North American childr...
# 12  b'Pediatric obesity is highly prevalent in dev...
# 13  b'Keywords Prevention \xc2\xb7 Childhood obesi...
# 14  b'Introduction/Background Systems thinking rep...
# 15  b'Background\r\nLittle evidence from developin...
# 16  b'Programming and implementation of health pol...
# 17  b'Keywords etiology; prevention; obesity; risk...

# %%
# the data needs to be preprocessed before any analysis can be performed

# forcing relevant fields to lowercase
dfPapers["title"] = toLower(dfPapers["title"])
dfPapers["abstract"] = toLower(dfPapers["abstract"])

# remove punctuation
dfPapers['title'] = removePunctuation(dfPapers['title'])
dfPapers['abstract'] = removePunctuation(dfPapers['abstract'])

# tokenise relevant data
dfPapers['title'] = tokenise(dfPapers['title'])
dfPapers['abstract'] = tokenise(dfPapers['abstract'])

# remove stop words
dfPapers['title'] = removeStops(dfPapers['title'])
dfPapers['abstract'] = removeStops(dfPapers['abstract'])


# errors are encountered here. stemming will improve the accuracy of the model, but we can still operate without it
# stem words
#ps = PorterStemmer()

# new dataframe for final processed data
#dfClean = dfPapers

#dfClean['title'] = dfPapers['title'].apply(lambda x: [ps.stem(y) for y in x])
#dfClean['abstract'] = dfPapers['abstract'].apply(lambda x: [ps.stem(y) for y in x])

# print processed data
print(dfPapers)
# Out:
#     id                                              title  \
# 0    1  (a, randomized, homebased, childhood, obesity,...
# 1    5  (a, threeyear, multifaceted, intervention, to,...
# 2    6  (a, behavioural, change, intervention, study, ...
# 3    7  (familybased, childhood, obesity, prevention, ...
# 4    8  (a, systematic, review, and, metaanalysis, of,...
# 5    9  (growing, healthy, together, protocol, for, a,...
# 6   10  (ob, citydefinition, of, a, familybased, inter...
# 7   11  (familybased, healthy, living, \r\n, intervent...
# 8   12  (short, and, longterm, beneficial, effects, of...
# 9   13  (effectiveness, of, a, kindergartenbased, inte...
# 10  14  (riding, into, health, a, case, study, on, an,...
# 11  15      (preventing, childhood, obesity, what, works)
# 12  17  (evaluation, and, treatment, of, severe, obesi...
# 13  18  (prevention, models, of, childhood, obesity, i...
# 14  19  (understanding, a, successful, obesity, preven...
# 15  20  (the, effect, of, comprehensive, intervention,...
# 16  21  (preventing, childhood, obesity, contributions...
# 17  22  (addressing, childhood, obesity, opportunities...
#
#                                                author  \
# 0   Lourdes Yun, Richard E. Boles, Matthew A. Haem...
# 1   Banafsheh Sadeghil, Lucia L. Kaiser, Meagan M....
# 2      Natisha Dukhi, Benn Sartorius, and Myra Taylor
# 3   Tayla Ash, Alen Agaronov, Ta’Loria Young, Alys...
# 4   Zheng Liu1, Han-Meng Xu, Li-Ming Wen, Yuan-Zho...
# 5   Byron A. Foster, Kelsey Weinstein and Jackilen...
# 6   RUOFEI HU, JORGE CANCELA, MARIA TERESA ARREDON...
# 7   Sam Liu, Isabela Gouveia Marques , Megan A Per...
# 8   Dan Nemet, Sivan Barkan, Yoram Epstein, Orit F...
# 9   Yan Hu, Jian-Rong He, Fang-Hua Liu, Wei-Dong L...
# 10  Katy Schroeder, Jason Van Allen, Emily Dhurand...
# 11                            LL Birch and AK Ventura
# 12              Edmond P. Wickham, and Mark D. DeBoer
# 13                                 Carl-Erik Flodmark
# 14  Brynle Owen, Andrew D. Brown, Jill Kuhlberg, L...
# 15  Haiquan Xu, Olivier Ecker, Qian Zhang, Songmin...
# 16          Muriel Lamarque, and Alicia Bibiana Orden
# 17  Callie L. Brown, Elizabeth E. Halvorson, Gail ...
#
#                                              abstract
# 0   (bbackground, although, colorado, is, perceive...
# 1   (bbackground, obesity, and, overweight, have, ...
# 2   (bbackground, south, africa, is, currently, un...
# 3   (bbackground, a, wide, range, of, intervention...
# 4   (bbackground, childhood, obesity, is, a, serio...
# 5   (bbackground, latino, children, in, the, us, e...
# 6   (babstract, childhood, obesity, is, becoming, ...
# 7   (bintroduction, familybased, behavioural, weig...
# 8   (bbackground, obesity, has, become, the, most,...
# 9   (bbackground, and, objectives, interventions, ...
# 10  (babstract, in, this, article, we, present, an...
# 11  (brates, of, overweight, in, north, american, ...
# 12  (bpediatric, obesity, is, highly, prevalent, i...
# 13  (bkeywords, prevention, xc2xb7, childhood, obe...
# 14  (bintroductionbackground, systems, thinking, r...
# 15  (bbackgroundrnlittle, evidence, from, developi...
# 16  (bprogramming, and, implementation, of, health...
# 17  (bkeywords, etiology, prevention, obesity, ris...

# %%
# calculate cosine similarities and print out for document 1

getSimilarity(0)
# Out:
# Similarities to Document 1
# Document 2, Title: a randomized homebased childhood obesity intervention delivered by patient navigators, Similarity: 0.962713185078254
# Document 3, Title: a randomized homebased childhood obesity intervention delivered by patient navigators, Similarity: 0.9638105260023572
# Document 4, Title: a randomized homebased childhood obesity intervention delivered by patient navigators, Similarity: 0.9449519892119711
# Document 5, Title: a randomized homebased childhood obesity intervention delivered by patient navigators, Similarity: 0.8583864570911615
# Document 6, Title: a randomized homebased childhood obesity intervention delivered by patient navigators, Similarity: 0.9659924798276139
# Document 7, Title: a randomized homebased childhood obesity intervention delivered by patient navigators, Similarity: 0.9404103219131492
# Document 8, Title: a randomized homebased childhood obesity intervention delivered by patient navigators, Similarity: 0.9167758717848711
# Document 9, Title: a randomized homebased childhood obesity intervention delivered by patient navigators, Similarity: 0.9173490698424637
# Document 10, Title: a randomized homebased childhood obesity intervention delivered by patient navigators, Similarity: 0.9417048822002425
# Document 11, Title: a randomized homebased childhood obesity intervention delivered by patient navigators, Similarity: 0.9346814660637827
# Document 12, Title: a randomized homebased childhood obesity intervention delivered by patient navigators, Similarity: 0.9388907397750368
# Document 13, Title: a randomized homebased childhood obesity intervention delivered by patient navigators, Similarity: 0.9257481632790104
# Document 14, Title: a randomized homebased childhood obesity intervention delivered by patient navigators, Similarity: 0.9146009980798595
# Document 15, Title: a randomized homebased childhood obesity intervention delivered by patient navigators, Similarity: 0.9527051674774718
# Document 16, Title: a randomized homebased childhood obesity intervention delivered by patient navigators, Similarity: 0.875757261119485
# Document 17, Title: a randomized homebased childhood obesity intervention delivered by patient navigators, Similarity: 0.9066591180354527
# Document 18, Title: a randomized homebased childhood obesity intervention delivered by patient navigators, Similarity: 0.9390451158511518
# <ipython-input-2-498551d5fe0a>:43: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   print("Document " + str(i+1) + ", Title: " + str(dfPapers['title'].loc[0]) + ", Similarity: " + str(doc1.similarity(doc2)))
